# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Untitled.ipynb']

# %%
import pandas

# %%
df1 = pandas.read_csv("supermarket.csv")
# Out:
# ------------------------------------
# FileNotFoundErrorTraceback (most recent call last)
# Cell In [3], line 1
# ----> 1 df1 = pandas.read_csv("supermarket.csv")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df1 = pandas.read_csv("supermarkets.csv")

# %%
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = read_json("supermarkets.json")
df2
# Out:
# ------------------------------------
# NameErrorTraceback (most recent call last)
# Cell In [7], line 1
# ----> 1 df2 = read_json("supermarkets.json")
#       2 df2
#
# NameError: name 'read_json' is not defined

# %%
df2 = pandas.read_json("supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3 = pandas.read_excel("supermarkets.xlsx")
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df3 = pandas.read_excel("supermarkets.xlsx"),sheet_name = 0
df3
# Out:
#   Cell In [10], line 1
#     df3 = pandas.read_excel("supermarkets.xlsx"),sheet_name = 0
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
df3 = pandas.read_excel("supermarkets.xlsx",sheet_name = 0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pandas.read_csv("data.txt", header = None)
df4
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df4.columns = ["ID", "Address", "City", "ZIP", "Country", "Name", "Employees"]
df4
# Out:
#    ID          Address           City               ZIP Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4.set_index("ID")
df4
# Out:
#    ID          Address           City               ZIP Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4.set_index("ID")
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df5= df4.set_index("ID")
df5
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df4
df5
# Out:
#             Address           City               ZIP Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 df4
#
# NameError: name 'df4' is not defined

# %%
import pandas as pd
df1 = pd.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = df1.loc[2:4,"City":"Country"]

# %%
df2
# Out:
#             City             State Country
# 2  San Francisco  California 94114     USA
# 3  San Francisco          CA 94114     USA
# 4  San Francisco        California     USA

# %%
df3= df1.drop("City",1)
df3
# Out:
# C:\Users\mahmu\AppData\Local\Temp\ipykernel_4992\2450725589.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df3= df1.drop("City",1)
#    ID          Address             State Country         Name  Employees
# 0   1     3666 21st St          CA 94114     USA      Madeira          8
# 1   2   735 Dolores St          CA 94119     USA  Bready Shop         15
# 2   3      332 Hill St  California 94114     USA  Super River         25
# 3   4     3995 23rd St          CA 94114     USA   Ben's Shop         10
# 4   5  1056 Sanchez St        California     USA      Sanchez         12
# 5   6  551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
df1.drop(2,0)
df1
# Out:
# C:\Users\mahmu\AppData\Local\Temp\ipykernel_4992\3238358045.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df1.drop(2,0)
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df1.drop(2,0)
# Out:
# C:\Users\mahmu\AppData\Local\Temp\ipykernel_4992\1451201943.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df1.drop(2,0)
#    ID          Address           City       State Country         Name  \
# 0   1     3666 21st St  San Francisco    CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco    CA 94119     USA  Bready Shop
# 3   4     3995 23rd St  San Francisco    CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco  California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco    CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 3         10
# 4         12
# 5         20

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df1.columns
# Out:
# Index(['ID', 'Address', 'City', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df1["Continent"] = df1.shape[0]*["North America"]
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees      Continent
# 0          8  North America
# 1         15  North America
# 2         25  North America
# 3         10  North America
# 4         12  North America
# 5         20  North America

# %%
df1["Situation"] = len(df1.index)*["Well"]

# %%
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees      Continent Situation
# 0          8  North America      Well
# 1         15  North America      Well
# 2         25  North America      Well
# 3         10  North America      Well
# 4         12  North America      Well
# 5         20  North America      Well

# %%
df1 = df1.drop("Situation", 1)
# Out:
# C:\Users\mahmu\AppData\Local\Temp\ipykernel_4992\3717469543.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df1 = df1.drop("Situation", 1)

# %%
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees      Continent
# 0          8  North America
# 1         15  North America
# 2         25  North America
# 3         10  North America
# 4         12  North America
# 5         20  North America

# %%
df1["Continent"] = df1["Country"] + ", " + df1["Continent"]
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees           Continent
# 0          8  USA, North America
# 1         15  USA, North America
# 2         25  USA, North America
# 3         10  USA, North America
# 4         12  USA, North America
# 5         20  USA, North America

# %%
df1_t=df1.T

# %%
df1_t
# Out:
#                             0                   1                   2  \
# ID                          1                   2                   3
# Address          3666 21st St      735 Dolores St         332 Hill St
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
#                             3                   4                   5
# ID                          4                   5                   6
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# ...

# %%
df1_t[7] = [7,"1 Park St", "Bursa", "Turkiye", "TC", "Home", 4, "TC, Europe"]

# %%
df1_t
# Out:
#                             0                   1                   2  \
# ID                          1                   2                   3
# Address          3666 21st St      735 Dolores St         332 Hill St
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
#                             3                   4                   5  \
# ID                          4                   5                   6
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# ...

# %%
df1 = df1_t.T

# %%
df1
# Out:
#   ID          Address           City             State Country         Name  \
# 0  1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1  2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2  3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3  4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4  5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5  6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
# 7  7        1 Park St          Bursa           Turkiye      TC         Home
#
#   Employees           Continent
# 0         8  USA, North America
# 1        15  USA, North America
# 2        25  USA, North America
# 3        10  USA, North America
# 4        12  USA, North America
# 5        20  USA, North America
# 7         4          TC, Europe

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()

# %%
import geopy
dir(geopy)
# Out:
# ['AlgoliaPlaces',
#  'ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'Geocodio',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'HereV7',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'What3WordsV3',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '__version_info__',
#  'adapters',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'get_version',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
help(ArcGIS)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [34], line 1
# ----> 1 help(ArcGIS)
#
# NameError: name 'ArcGIS' is not defined

# %%
import geopy as gp
help(gp.ArcGIS)
# Out:
# Help on class ArcGIS in module geopy.geocoders.arcgis:
#
# class ArcGIS(geopy.geocoders.base.Geocoder)
#  |  ArcGIS(username=None, password=None, *, referer=None, token_lifetime=60, scheme=None, timeout=DEFAULT_SENTINEL, proxies=DEFAULT_SENTINEL, user_agent=None, ssl_context=DEFAULT_SENTINEL, adapter_factory=None, auth_domain='www.arcgis.com', domain='geocode.arcgis.com')
#  |
#  |  Geocoder using the ERSI ArcGIS API.
#  |
#  |  Documentation at:
#  |      https://developers.arcgis.com/rest/geocode/api-reference/overview-world-geocoding-service.htm
#  |
#  |  Method resolution order:
#  |      ArcGIS
#  |      geopy.geocoders.base.Geocoder
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, username=None, password=None, *, referer=None, token_lifetime=60, scheme=None, timeout=DEFAULT_SENTINEL, proxies=DEFAULT_SENTINEL, user_agent=None, ssl_context=DEFAULT_SENTINEL, adapter_factory=None, auth_domain='www.arcgis.com', domain='geocode.arcgis.com')
# ...

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()

# %%
df1
# Out:
#   ID          Address           City             State Country         Name  \
# 0  1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1  2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2  3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3  4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4  5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5  6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
# 7  7        1 Park St          Bursa           Turkiye      TC         Home
#
#   Employees           Continent
# 0         8  USA, North America
# 1        15  USA, North America
# 2        25  USA, North America
# 3        10  USA, North America
# 4        12  USA, North America
# 5        20  USA, North America
# 7         4          TC, Europe

# %%
nom.geocode("3995 23rd St, San Francisco, CA 94114")
# Out:
# Location(3995 23rd St, San Francisco, California, 94114, (37.75292099814533, -122.43170295955227, 0.0))

# %%
nom.geocode("1.Park Sokak, Bursa, 16400").longitude
# Out:
# 29.50077263475519

# %%
nom.geocode("1.Park Sokak, Bursa, 16400").altitude
# Out:
# 0.0

# %%
nom.geocode("1.Park Sokak, Bursa, 16400").latitude
# Out:
# 40.08416908178123

# %%
df = pd.read_csv("supermarkets.csv")

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"] = df["Address"] + ", " + df["City"] + ", " + df["State"]

# %%
df
# Out:
#    ID                                       Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"] = df["Address"].apply(nom.geocode)

# %%
df
# Out:
#    ID                                       Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates
# 0  (3666 21st St, San Francisco, California, 9411...
# ...

# %%
df["Coordinates"][1]
# Out:
# Location(735 Dolores St, San Francisco, California, 94110, (37.757828979640195, -122.4253730300932, 0.0))

# %%
df["Latitude"] = df["Coordinates"].apply(lambda x: x.latitude if x !=  None else None)
df
# Out:
#    ID                                       Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude
# ...

# %%
df["Longitude"] = df["Coordinates"].apply(lambda x: x.longitude if x != None else None)
df
# Out:
#    ID                                       Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...
